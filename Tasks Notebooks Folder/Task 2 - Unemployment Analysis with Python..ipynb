# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:brown;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Unemployment In India Analysis.
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:Georgia;background-color:aliceblue; padding:30px; font-size:17px">
#
# <b>Task 2 Objective:-Unemployement Analysis with Python.<br>
#
# <b>Description</b><br>
#
# 💡 Unemployment is measured by the unemployment rate which is the number of people who are unemployed as a percentage pf the total labour force.<br>
# 💡 During the covid-19 period there was a sharp increase in the unemployment rate.<br>
# 💡 So in this assignment we have to analyze the unemployment rate using python.<br>
# 💡 Dataset Link:- https://www.kaggle.com/datasets/gokulrajkmv/unemployment-in-india<br>
#
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color:aliceblue;"><b> Author:- </b> Kumod Sharma</h2>
# </div>

# %% [markdown]
# <center>
# <img src="https://img.etimg.com/thumb/width-1200,height-900,imgsize-48766,resizemode-1,msid-92257881/news/economy/indicators/unemployment-rate-in-urban-india-in-the-january-march-quarter-of-2021-22-fell-to-8-2.jpg" width=600 height=400 />
# </center>

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Importing Libraries
# </p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import calendar
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
sns.set(style="darkgrid",font_scale=1.5)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Loading Datasets
# </p>
# </div>

# %%
df = pd.read_csv("C:\\Users\\kumod sharma\\Desktop\\Unemployment in India.csv")

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139                                     43.24  Rural
# 1             11755881                                     42.05  Rural
# 2             12086707                                     43.50  Rural
# 3             12285693                                     43.97  Rural
# 4             12256762                                     44.68  Rural

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Basic Understanding of Data
# </p>
# </div>

# %% [markdown]
# ### 1. Checking the dimension of the dataset.

# %%
df.shape
# Out:
# (740, 7)

# %% [markdown]
# **Observation**
# * From the above output we can say that there are **768 Records/Rows** & **7 Attributes//columns**

# %% [markdown]
# ### 2. Showing the first 5 records.

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139                                     43.24  Rural
# 1             11755881                                     42.05  Rural
# 2             12086707                                     43.50  Rural
# 3             12285693                                     43.97  Rural
# 4             12256762                                     44.68  Rural

# %% [markdown]
# ### 3. Showing the bottom 5 records.

# %%
df.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 735  West Bengal   29-02-2020    Monthly                              7.55
# 736  West Bengal   31-03-2020    Monthly                              6.67
# 737  West Bengal   30-04-2020    Monthly                             15.63
# 738  West Bengal   31-05-2020    Monthly                             15.22
# 739  West Bengal   30-06-2020    Monthly                              9.86
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 735             10871168                                     44.09  Urban
# 736             10806105                                     43.34  Urban
# 737              9299466                                     41.20  Urban
# 738              9240903                                     40.67  Urban
# 739              9088931                                     37.57  Urban

# %% [markdown]
# ### 4. Checking the Data-Types of the Features.

# %%
df.dtypes.to_frame().rename(columns={0:"Data-Types"})
# Out:
#                                          Data-Types
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                           int64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object

# %% [markdown]
# **Observation**
# * We can observe that the **Date feature** is having data-type of **object** which is not correct. So we have to update it.
# * Other Features are having the correct Data-Types.

# %% [markdown]
# ### 5. Checking Missing Values.

# %%
df.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing values"})
# Out:
#                                           Total No. of Missing values
# Region                                                              0
#  Date                                                               0
#  Frequency                                                          0
#  Estimated Unemployment Rate (%)                                    0
#  Estimated Employed                                                 0
#  Estimated Labour Participation Rate (%)                            0
# Area                                                                0

# %% [markdown]
# **Observation**
# * We can observe that there are **No missing values present** in our dataset.

# %% [markdown]
# ### 6. Checking Duplicate Values.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Observation**
# * We can clearly observe that there is **no duplicate values** present in our dataset.

# %% [markdown]
# ### 7. Checking the Attribute Names

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %% [markdown]
# **Observation**
# * We have to rename two Attributes because we have an extra space in thee columns names:-
# 1. `Region` = `States`
# 2. `  Date` = `Date`
# 3. `  Estimated Unemployment Rate (%)` = `Estimated Unemployment Rate (%)`
# 4. `  Estimated Employed` = `Estimated Employed`
# 5. `  Estimated Labour Participation Rate (%)` = `Estimated Labour Participation Rate (%)`

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Data Wrangling
# </p>
# </div>

# %% [markdown]
# ### 1. Changing the Attribute Names.

# %%
df.rename(columns={"Region":"States"," Date":"Date"," Estimated Unemployment Rate (%)":"Estimated Unemployment Rate (%)",
                  " Estimated Employed":"Estimated Employed"," Estimated Labour Participation Rate (%)":
                   "Estimated Labour Participation Rate (%)"},inplace=True)

# %%
df.head()
# Out:
#            States         Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                             3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                             3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                             3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                             3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0            11999139                                    43.24  Rural
# 1            11755881                                    42.05  Rural
# 2            12086707                                    43.50  Rural
# 3            12285693                                    43.97  Rural
# 4            12256762                                    44.68  Rural

# %% [markdown]
# ### 2. Changing the Data-Type of Date Attribute.

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)

# %% [markdown]
# ### 3. Extracting Month from the Date Attribute.

# %%
df["Month"] = df["Date"].dt.month

# %%
df.head()
# Out:
#            States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  Month
# 0            11999139                                    43.24  Rural      5
# 1            11755881                                    42.05  Rural      6
# 2            12086707                                    43.50  Rural      7
# 3            12285693                                    43.97  Rural      8
# 4            12256762                                    44.68  Rural      9

# %% [markdown]
# **Observation**
# * We can observe that the months are extracted but they are in numbers.
# * So we need to update it in months names for better analysis.

# %% [markdown]
# ### 4. Updating Months to Months Name.

# %%
df['Month_Name'] =  df['Month'].apply(lambda x: calendar.month_abbr[x])

# %%
df.head()
# Out:
#            States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  Month  \
# 0            11999139                                    43.24  Rural      5
# 1            11755881                                    42.05  Rural      6
# 2            12086707                                    43.50  Rural      7
# 3            12285693                                    43.97  Rural      8
# 4            12256762                                    44.68  Rural      9
#
#   Month_Name
# 0        May
# 1        Jun
# 2        Jul
# ...

# %% [markdown]
# **Note**
# * Since we have obtained the Month Names we can drop the Months integer value Attribute.

# %% [markdown]
# ### 5. Dropping the Months Attribute.

# %%
df.drop(columns="Month",inplace=True)

# %% [markdown]
# ### 6. Checking Unique Months.

# %%
df["Month_Name"].unique()
# Out:
# array(['May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan',
#        'Feb', 'Mar', 'Apr'], dtype=object)

# %% [markdown]
# ### 7. Extracting Years From the Date Attribute.

# %%
df["Year"] = df["Date"].dt.year

# %%
df.head()
# Out:
#            States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  \
# 0            11999139                                    43.24  Rural
# 1            11755881                                    42.05  Rural
# 2            12086707                                    43.50  Rural
# 3            12285693                                    43.97  Rural
# 4            12256762                                    44.68  Rural
#
#   Month_Name  Year
# 0        May  2019
# 1        Jun  2019
# 2        Jul  2019
# 3        Aug  2019
# ...

# %% [markdown]
# ### 8. Checking Unique Years.

# %%
df["Year"].unique()
# Out:
# array([2019, 2020], dtype=int64)

# %% [markdown]
# ### 9. Checking the Unique Values in States Feature.

# %%
df["States"].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %% [markdown]
# ### 10. Checking Unique Values in Area Attribute.

# %%
df["Area"].unique()
# Out:
# array(['Rural', 'Urban'], dtype=object)

# %% [markdown]
# ### 11. Basic Descriptive Stats of Numerical Feature.

# %%
round(df.select_dtypes(include=["float","int"]).describe().T,2)
# Out:
#                                          count        mean         std  \
# Estimated Unemployment Rate (%)          740.0       11.79       10.72
# Estimated Employed                       740.0  7204460.03  8087988.43
# Estimated Labour Participation Rate (%)  740.0       42.63        8.11
# Year                                     740.0     2019.42        0.49
#
#                                               min         25%         50%  \
# Estimated Unemployment Rate (%)              0.00        4.66        8.35
# Estimated Employed                       49420.00  1190404.50  4744178.50
# Estimated Labour Participation Rate (%)     13.33       38.06       41.16
# Year                                      2019.00     2019.00     2019.00
#
#                                                  75%          max
# Estimated Unemployment Rate (%)                15.89        76.74
# Estimated Employed                       11275489.50  45777509.00
# ...

# %% [markdown]
# **Observations**
# * We can observe that the **maxium unemployment rate was almost near to 77%** which is very huge. It menas that more than 3/4 of employees layoffs were done.
#
# * We can also observe that the **maximum labour rate was almost near to 73%** which is very huge.
#
# **Insights**
# * We can fetch those state names having those kind of drastic rate values.

# %% [markdown]
# ### 12. Fetching State Name having those Drastic Unemplyment & Labours Rate.

# %%
df[df["Estimated Unemployment Rate (%)"]>76]
# Out:
#          States       Date  Frequency  Estimated Unemployment Rate (%)  \
# 613  Puducherry 2020-04-30    Monthly                            76.74
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area  \
# 613               68122                                    35.54  Urban
#
#     Month_Name  Year
# 613        Apr  2020

# %% [markdown]
# **Insight**
# * **Puducherry** is having that drastic **Decrement in Unemployment Rate** in the month of **April 2020**.

# %% [markdown]
# ### 13. Basic Descriptive Stats w.r.t States

# %%
round(df.groupby(["States"])[["Estimated Unemployment Rate (%)","Estimated Employed",
                              "Estimated Labour Participation Rate (%)"]].mean(),2).sort_values(by="Estimated Unemployment Rate (%)",ascending=False)
# Out:
#                   Estimated Unemployment Rate (%)  Estimated Employed  \
# States
# Tripura                                     28.35           717002.64
# Haryana                                     26.28          3557072.46
# Jharkhand                                   20.58          4469240.43
# Bihar                                       18.92         12366189.14
# Himachal Pradesh                            18.54          1059823.71
# Delhi                                       16.50          2627512.86
# Jammu & Kashmir                             16.19          1799931.67
# Chandigarh                                  15.99           316831.25
# Rajasthan                                   14.06         10041064.75
# Uttar Pradesh                               12.55         28094832.18
# Punjab                                      12.03          4539362.00
# Puducherry                                  10.22           212278.08
# ...

# %% [markdown]
# **Insights**
# * `Tripura` was having the **highest avergae amount of Unemployment Rate**
# * `Meghalaya` was having the **lowest average amount of Unemployment Rate**

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Exploratory Data Analysis (EDA)
# </p>
# </div>

# %% [markdown]
# ### 1. Visualizing Average Employement Rate State Wise.

# %%
x = df.groupby(["States"])["Estimated Unemployment Rate (%)"].mean().sort_values(ascending=False).to_frame()
plt.figure(figsize=(15,6))
sns.barplot(x.index,x["Estimated Unemployment Rate (%)"],palette=sns.color_palette("Reds",28)[::-1])
plt.title("State wise Average Unemployment Rate",fontweight="black",fontsize=20,pad=10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insights**
# 1. We can clearly observe that **Tripura** is having the **Highest Average Unemplyment Rate** followed by **Haryana**.
# 2. **Meghalaya** state is having the **lowest Average Unemplyment Rate** followed by **Odisha**.

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Visualizing State Wise Average Labour Particiaption Rate.

# %%
x = df.groupby(["States"])["Estimated Labour Participation Rate (%)"].mean().sort_values(ascending=False).to_frame()
plt.figure(figsize=(15,6))
sns.barplot(x.index,x["Estimated Labour Participation Rate (%)"],palette=sns.color_palette("Reds",28)[::-1])
plt.title("State wise Average Labour Participation Rate",fontweight="black",fontsize=20,pad=10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insights**
# * We can observe that **Tripura** is having the highest Labour participation Rate followed by **Meghalaya**.
# * We can also observe that **uttarakhand** is having the lowest Labour participation Rate followed by **Kerala**.

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Visualizing State Wise Total Estimated Employed.

# %%
x = df.groupby(["States"])["Estimated Employed"].sum().sort_values(ascending=False).to_frame()
plt.figure(figsize=(15,6))
sns.barplot(x.index,x["Estimated Employed"],palette=sns.color_palette("Reds",28)[::-1])
plt.title("State wise Total Estimated Employed",fontweight="black",fontsize=20,pad=10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insights**
# 1. We can observe that **Uttar Pradesh** is having the highest total estimated employed followed by **Maharashtra**.
# 2. **Sikkim** is having the lowest total estimated employed followed by **chandigarh**
# 3. So we can make an insight that **estimated employe** is totally dependend on **populatuion**

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Visualizing Average "Unemployment Rate" & "Labour Participation" Rate w.r.t Area.

# %%
x = df.groupby(["Area"])["Estimated Unemployment Rate (%)"].mean().sort_values(ascending=False).to_frame()
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.barplot(x.index,x["Estimated Unemployment Rate (%)"],palette=sns.color_palette("Reds",3)[::-1])
plt.title("State wise Average Unemployment Rate",fontweight="black",fontsize=15,pad=10)
plt.xticks(rotation=90)

z = df.groupby(["Area"])["Estimated Labour Participation Rate (%)"].mean().sort_values(ascending=False).to_frame()
plt.subplot(1,2,2)
sns.barplot(z.index,z["Estimated Labour Participation Rate (%)"],palette=sns.color_palette("Reds",3)[::-1])
plt.title("State wise Average Labour Participation Rate",fontweight="black",fontsize=15,pad=10)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**
# 1. We can clearly observe that **Urban Area** is having **more Unemployment Rate** when compared with **Rural Area**.
# 2. But when it comes to **Labour Participation Rate** , **Rural Area** is having more labours when compared with **Urban Area**
#
# **Insights**
# * **Urban Area** is having more **Unemployment Rate** even though of low **labour rate** when compared with **Rural Area**.

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Visualizing Unemployment and Labour Rate throughout the years.

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
ax = sns.lineplot(df["Year"],df["Estimated Unemployment Rate (%)"],color="red")
ax.set_xticklabels(["","2019","","","","","2020"])
plt.title("Unemployment Rate Over the Years",fontweight="black",fontsize=20,pad=10)

plt.subplot(1,2,2)
ax = sns.lineplot(df["Year"],df["Estimated Labour Participation Rate (%)"],color="magenta")
ax.set_xticklabels(["","2019","","","","","2020"])
plt.title("Labour Rate Over the Years",fontweight="black",fontsize=20,pad=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**
# 1. From first plot we can clearly observe that there was a **Hige increment in Unemployment over the years**.
# 2. From second plot we can clarly observe that there was a **Huge decrement in Labour Rate over the years**
#
# **Insights**
# * So we can make an insight that the Unemployment rate has **increased to double from 2019 to 2020**. And the **Labour Rate decreased drastically from 2019 to 2020**

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Visualizing Unemployment & Labour Rate in 2019 throughout the months.

# %%
x = df[df["Year"]==2019]
y = df[df["Year"]==2020]

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.lineplot(x["Month_Name"],x["Estimated Unemployment Rate (%)"],color="red")
plt.title("Unemployment Rate over the Months in 2019",fontweight="black",fontsize=15,pad=10)

plt.subplot(1,2,2)
sns.lineplot(x["Month_Name"],x["Estimated Labour Participation Rate (%)"],color="magenta")
plt.title("Labour Rate over the Months in 2019",fontweight="black",fontsize=15,pad=10)
plt.show()

# %% [markdown]
# **Observations**
# 1. From first plot we can observe that there was **increment and decrement in Unemployment Rate throughout the Months in 2019**
# 2. From the second plot we can observe that there was **increment and decrement in Labour Rate throughout the Months in 2019**.
#
# **Insights**
# * We can make an insight that before **corona-virus came in India the Unemployment Rate & the Labour Rate** was **not affected that much.**

# %% [markdown]
# ---

# %% [markdown]
# ### 7. Visualizing Unemployment & Labour Rate in 2020 throughout the months.

# %%
x = df[df["Year"]==2020]

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.lineplot(x["Month_Name"],x["Estimated Unemployment Rate (%)"],color="red")
plt.title("Unemployment Rate over the Months in 2019",fontweight="black",fontsize=15,pad=10)

plt.subplot(1,2,2)
sns.lineplot(x["Month_Name"],x["Estimated Labour Participation Rate (%)"],color="magenta")
plt.title("Labour Rate over the Months in 2019",fontweight="black",fontsize=15,pad=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**
# 1. From the first plot we can clearly observe that in the month of **March to May in 2020** there was a **huge increment in Unemployment Rate**
# 2. From the second plot we can clearly observe that in the month of **March to April in 2020** there was a **huge decrement in Labour Rate**
#
# **Insights**
# * We know that **COVID-19 came in India in the month of January in 2020** and the **first nationwide lockdown in India was announced by Prime Minister Narendra Modi on March 24, 2020**, in response to the COVID-19 pandemic.
# * So we can make an insight that due to the **COVID-19 Lockdown** there was a **huge increment in Unemployment Rate** and **Huge Decrement in Labour Rate**.

# %% [markdown]
# ---

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:150%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 15px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Impact of COVID-19 Lockdown in Unemployment Rate in India
# </p>
# </div>

# %% [markdown]
# ### 1. Visualizing  States Wise Increment in Unemployment Rate During the Lockdown.

# %%
x = df[(df["Year"]==2020) & ((df["Date"].dt.month)>=3)]

z = x.groupby(["States"])["Estimated Unemployment Rate (%)"].mean().sort_values(ascending=False).to_frame()

plt.figure(figsize=(13,10))
sns.barplot(z["Estimated Unemployment Rate (%)"],z.index,palette=sns.color_palette("Reds",30)[::-1])
plt.title("Most Affected States/UT of India During the COVID-19 Lockdown in terms of Unemployment Rate",
          fontweight="black",fontsize=20,pad=20)
plt.show()

# %% [markdown]
# **Insights**
# * Top 5 most affected states/UT during the COVID-19 Lockdown in terms of **Unemployment Rate** are:-
# > `Puducherry`<br>
# > `Jharkhand`<br>
# > `Haryana`<br>
# > `Bihar`<br>
# > `Tripura`<br>

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Visualizing  States Wise Increment in Labour Rate During the Lockdown.

# %%
x = df[(df["Year"]==2020) & ((df["Date"].dt.month)>=3)]

z = x.groupby(["States"])["Estimated Labour Participation Rate (%)"].mean().sort_values(ascending=False).to_frame()

plt.figure(figsize=(14,10))
sns.barplot(z["Estimated Labour Participation Rate (%)"],z.index,palette=sns.color_palette("Reds",30)[::-1])
plt.title("Most Affected States/UT of India During the COVID-19 Lockdown in terms of Labour Rate",
          fontweight="black",fontsize=20,pad=30)
plt.show()

# %% [markdown]
# **Insights**
# * Top 5 most affected states/UT during the COVID-19 Lockdown in terms of **Labour Rate** are:-
# > `Tripura`<br>
# > `Meghalaya`<br>
# > `Telangana`<br>
# > `Karnatak`<br>
# > `Assam`<br>

# %% [markdown]
# ---

# %% [markdown]
# <a id="1.1"></a>
# <h2 style="font-family: Verdana; font-size: 28px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>Conclusion:-</b>
#  </h2>

# %% [markdown]
# <div style="font-family:Georgia;background-color:aliceblue; padding:30px; font-size:17px">
#
# <b>Unemployment Analysis in India using Python</b><br>
#
# <b>Key-Points</b><br>
#
# 💡 First we did the <b>Basic Understanding</b> of the dataset.<br>
# 💡 Then we performed <b>Data Wrangling</b> and did all the cleaning and statistical analysis.<br>
# 💡 Then we performed <b>Exploratory Data Analysis</b> to generaate the insights.<br>
# 💡 In the end we generated an insight that <b>Most of states were having drastic increment in Unemployment Rate during the Lockdown.</b>
# </div>

# %% [markdown]
# ---
